# %% [markdown]
# ## Some random Notebook

# %%
import pandas as pd
import numpy as np

# %%
df_path = "/Users/sandrohunziker/hydrosolutions Dropbox/Sandro Hunziker/SAPPHIRE_Central_Asia_Technical_Work/data/taj_data_forecast_tools/intermediate_data/runoff_day.csv"

df = pd.read_csv(df_path)

# %%
print(df.head())
# Out:
#     code        date  discharge
# 0  16006  1956-01-01      473.0
# 1  16006  1956-01-02      465.0
# 2  16006  1956-01-03      458.0
# 3  16006  1956-01-04      451.0
# 4  16006  1956-01-05      443.0

# %%
print("Unique Codes:")
print(np.unique(df["code"]))
# Out:
# Unique Codes:
# [16006 16013 17050 17075 17082 17084 17100 17110 17137 17147 17150 17202
#  17288 17325 17329 17338 17344 17453]

# %%
df_path_2 = "/Users/sandrohunziker/hydrosolutions Dropbox/Sandro Hunziker/SAPPHIRE_Central_Asia_Technical_Work/data/taj_data_forecast_tools/intermediate_data/predictions/TFT/decad_TFT_forecast.csv"

df_2 = pd.read_csv(df_path_2)

print(df_2.head())

print("Unique Codes:")
print(np.unique(df_2["code"]))
# Out:
#       Q5    Q10    Q15    Q20    Q25    Q30    Q35    Q40    Q45    Q50  ...  \
# 0  12.86  13.12  13.17  13.31  13.38  13.43  13.48  13.53  13.56  13.62  ...
# 1  23.77  23.84  23.90  24.00  24.03  24.07  24.11  24.14  24.16  24.18  ...
# 2   6.21   6.34   6.41   6.48   6.55   6.63   6.68   6.71   6.75   6.78  ...
# 3   6.42   6.51   6.56   6.63   6.70   6.75   6.79   6.82   6.86   6.88  ...
# 4   6.38   6.53   6.60   6.66   6.72   6.74   6.76   6.79   6.84   6.87  ...
#
#      Q70    Q75    Q80    Q85    Q90    Q95        date  forecast_date   code  \
# 0  13.75  13.82  13.90  13.94  14.01  14.15  2009-12-31     2009-12-30  17325
# 1  24.26  24.28  24.33  24.37  24.43  24.50  2010-01-07     2009-12-30  17453
# 2   6.95   6.98   7.02   7.06   7.12   7.21  2010-01-06     2009-12-30  17344
# 3   7.01   7.03   7.07   7.14   7.21   7.28  2010-01-05     2009-12-30  17344
# 4   6.96   6.97   7.01   7.08   7.11   7.25  2010-01-04     2009-12-30  17344
#
#   flag
# 0    4
# 1    4
# 2    4
# ...

# %%
df_with_code_0 = df_2[df_2["code"] == 0].copy()

print(len(df_with_code_0))
# Out:
# 63690

# %%
def remove_code_0_and_save(df_path):
    df = pd.read_csv(df_path)
    df["code"] = df["code"].astype(int)
    df = df[df["code"] != 0].copy()
    df.to_csv(df_path, index=False)


paths = [
    "/Users/sandrohunziker/hydrosolutions Dropbox/Sandro Hunziker/SAPPHIRE_Central_Asia_Technical_Work/data/taj_data_forecast_tools/intermediate_data/predictions/TFT/decad_TFT_forecast.csv",
    "/Users/sandrohunziker/hydrosolutions Dropbox/Sandro Hunziker/SAPPHIRE_Central_Asia_Technical_Work/data/taj_data_forecast_tools/intermediate_data/predictions/TFT/pentad_TFT_forecast.csv",
    "/Users/sandrohunziker/hydrosolutions Dropbox/Sandro Hunziker/SAPPHIRE_Central_Asia_Technical_Work/data/taj_data_forecast_tools/intermediate_data/predictions/TIDE/decad_TIDE_forecast.csv",
    "/Users/sandrohunziker/hydrosolutions Dropbox/Sandro Hunziker/SAPPHIRE_Central_Asia_Technical_Work/data/taj_data_forecast_tools/intermediate_data/predictions/TIDE/pentad_TIDE_forecast.csv",
    "/Users/sandrohunziker/hydrosolutions Dropbox/Sandro Hunziker/SAPPHIRE_Central_Asia_Technical_Work/data/taj_data_forecast_tools/intermediate_data/predictions/TSMIXER/decad_TSMIXER_forecast.csv",
    "/Users/sandrohunziker/hydrosolutions Dropbox/Sandro Hunziker/SAPPHIRE_Central_Asia_Technical_Work/data/taj_data_forecast_tools/intermediate_data/predictions/TSMIXER/pentad_TSMIXER_forecast.csv",
]

for path in paths:
    remove_code_0_and_save(path)
